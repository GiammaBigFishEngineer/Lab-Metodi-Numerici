# %%
# %run ex.py
# Out:
# [1, 1, 2, 3]
# [1, 1, 2, 3, 5, 8, 13]
# [4, 16, 36, 64, 100]
#
#
# *
#
# * *
#
# * * *
#
# * * * *
#
# * * * * *
#
# * * * *
#
# * * *
#
# * *
#
# *
#
#
#
# not ok
# 300
# 20000
# (28, 5040)
